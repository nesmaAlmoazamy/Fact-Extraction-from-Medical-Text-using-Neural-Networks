# %%
import csv
import numpy as np
import pandas as pd

# %%
# extract = pd.read_csv("egcut_epi_nesma_extracted_features_example.csv",header=None)
# extract.columns = ["text_ID","start","end","object","value","unit","min","max"]
# text = pd.read_csv("egcut_epi_nesma_texts_example.csv",header=None)
# text.columns = ["text_ID","text"]
# text = text.drop_duplicates(subset='text_ID', keep='first')
# DS = pd.merge(extract, text, how="left", on='text_ID')
# DS.to_csv("MergedDS.csv",index=False)

# %%
DS = pd.read_csv("MergedDS.csv")

# %%
DSSubset = DS[1:500]

# %%
DSSubset.head()
# Out:
#    text_ID  start  end object  value unit  min  max  \
# 1    45389    165  171     RR  110.0  NaN  NaN  NaN
# 2    47482      0    5     RR  142.0  NaN  NaN  NaN
# 3    53393      0    5     RR  143.0  NaN  NaN  NaN
# 4    53571      0    6     RR  140.0  NaN  NaN  NaN
# 5    71834    697  702     RR   95.0  NaN  NaN  NaN
#
#                                                 text
# 1  Kergelt liigkaaluline. Nahk, limaskestad taval...
# 2  RR142/89mmHg, HR 76 x min, p167cm, k89kg.  EKG...
# 3            RR143/87mmHg, HR60 x min, p180cm, k93kg
# 4  RR 140/74 mm Hg Cor fr. 62 UH uuringul kaela a...
# 5  \n                Patsient hospitaliseeritud e...

# %% [markdown]
# ### To do: We need to take the text which is mosly annotated

# %%
# DS.sort_values('text_ID')[1:50]

# %%
# DSSubset['text'] =  DSSubset['text'].str.strip()
# DSSubset['text'].replace('\n','', regex=True,inplace = True)
# DSSubset['text'].replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True,inplace = True)

# %%
new_df = pd.DataFrame(DSSubset["text"].str.split().tolist(), index=DSSubset.text_ID).stack()

# %%
new_df = new_df.reset_index([0, 'text_ID'])

# %%
new_df.columns = ['text_ID', 'word']

# %%
new_df[200:230]
# Out:
#      text_ID                    word
# 200    71834  rahulikum,agresiivsust
# 201    71834                      ei
# 202    71834                 avalda.
# 203    71834                Ravimeid
# 204    71834               tarvitab.
# 205    71834                     Uni
# 206    71834                endiselt
# 207    71834            ärkamistega,
# 208    71834                   Haige
# 209    71834                    nõus
# 210    71834                 jätkama
# 211    71834                    ravi
# 212    71834         ambulatoorselt.
# 213    71834                  Jätkab
# 214    71834                    ravi
# 215    71834                Orfirili
# 216    71834                   600mg
# 217    71834            h,Ketipinori
# 218    71834                   300mg
# 219    71834               H,õ,200mg
# 220    71834               L,Leponex
# 221    71834                   100mg
# 222    71834             h,öö,75mgL,
# 223    71834                Cyclidol
# ...

# %%
new_df["start"]= np.NaN
new_df["end"]= np.NAN
new_df
# Out:
#        text_ID            word  start  end
# 0        45389         Kergelt    NaN  NaN
# 1        45389  liigkaaluline.    NaN  NaN
# 2        45389           Nahk,    NaN  NaN
# 3        45389     limaskestad    NaN  NaN
# 4        45389        tavalist    NaN  NaN
# ...        ...             ...    ...  ...
# 63908     1954     meloksikaam    NaN  NaN
# 63909     1954        (Movalis    NaN  NaN
# 63910     1954             7,5    NaN  NaN
# 63911     1954            mg)N    NaN  NaN
# 63912     1954             50.    NaN  NaN
#
# [63913 rows x 4 columns]

# %%
# new_df["word"].replace('', np.nan,inplace=True)
# new_df = new_df.dropna(subset=['word'])
# new_df = new_df.reset_index(drop=True)

# %%
prev = 0
for i in range(1,len(new_df)):
    if(new_df["text_ID"][i-1] == new_df["text_ID"][i]):
        wordLen = len(new_df.word[i])
        new_df["start"][i] = prev 
        new_df["end"][i] = prev  + wordLen
        prev = new_df["end"][i] + 1
    else: 
        prev = 0
        wordLen = len(new_df.word[i])
        new_df["start"][i] = prev 
        new_df["end"][i] = prev  + wordLen
        prev = new_df["end"][i] + 1
# Out:
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# *

# %%
new_df["tag"] = np.NaN

# %%
# col_names = list(new_df.columns)
# Processed_DF = pd.DataFrame(columns = col_names)
# Processed_DF

# %%
myList= list(DSSubset.text_ID.unique())

for i in range(len(myList)):
# for i in range(1,5):
    Original = DSSubset.loc[DSSubset["text_ID"] == myList[i]]
    words = new_df.loc[new_df["text_ID"] == myList[i]]
#     print(words)
    for OriginalIndex, OriginalRow in Original.iterrows():
        for index, row in words.iterrows():
                if(words["start"][index] in range(Original["start"][OriginalIndex],Original["end"][OriginalIndex]) or words["end"][index] in range(Original["start"][OriginalIndex],Original["end"][OriginalIndex]) ):
                    new_df["tag"][index] = "Target"
# Out:
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
# DS["objVal"] = DS["object"].astype(str) +" "+DS["value"].astype(str)
# DSMerged = DS.groupby(['text_ID','text'], as_index = False).agg({'objVal': ' , '.join})

# %%
len(new_df)
# Out:
# 63913

# %%
new_df[new_df["tag"] == "Target"][200:250]
# Out:
#        text_ID            word   start     end     tag
# 14291  347473   Säärel          0.0     6.0     Target
# 14362  353718   84/50           576.0   581.0   Target
# 14462  357844   :               9.0     10.0    Target
# 14463  357844   60              11.0    13.0    Target
# 14466  357843   ja              7.0     9.0     Target
# 14467  357843   liigessüsteem,  10.0    24.0    Target
# 14494  357842   21.05.2014      0.0     10.0    Target
# 14495  357842   N.              11.0    13.0    Target
# 14496  357842   <ANONYM         14.0    21.0    Target
# 14511  357847   ja              7.0     9.0     Target
# 14512  357847   liigessüsteem,  10.0    24.0    Target
# 14523  357845   28.07.2014      0.0     10.0    Target
# 14524  357845   N.              11.0    13.0    Target
# 14525  357845   <ANONYM         14.0    21.0    Target
# 14606  366704   116/66mmHg,     557.0   568.0   Target
# 14607  366704   kuid            569.0   573.0   Target
# ...

# %%
new_df[new_df["text_ID"] == 357842]
# Out:
#        text_ID                    word  start    end     tag
# 14494  357842   21.05.2014              0.0    10.0   Target
# 14495  357842   N.                      11.0   13.0   Target
# 14496  357842   <ANONYM                 14.0   21.0   Target
# 14497  357842   id="2"                  22.0   28.0   NaN
# 14498  357842   type="per"              29.0   39.0   NaN
# 14499  357842   morph="_H_              40.0   50.0   NaN
# 14500  357842   sg                      51.0   53.0   NaN
# 14501  357842   n"/>                    54.0   58.0   NaN
# 14502  357842   D00330                  59.0   65.0   NaN
# 14503  357842   Kardiovaskulaarsüsteem  66.0   88.0   NaN
# 14504  357842   Südame                  89.0   95.0   NaN
# 14505  357842   auskultatsioon          96.0   110.0  NaN
# 14506  357842   ja                      111.0  113.0  NaN
# 14507  357842   perkussioon             114.0  125.0  NaN
# 14508  357842   normis                  126.0  132.0  NaN

# %%
len("Plaaniline haige kõrgenenud vererõhu väärtuste ja valudega südame piirkonnas viimaste nädalate välte.Anamneesis juba aastaid diabeet ja kõrgenenud vererõhk. Valga haiglas kaks aastat tagasi samade kaebustega, peale mida teostatud TÜK-s koronaograafia. Saabudes rahuldavas üldseisundis,pükniline kehaehitus, adekvaatselt kontaktne, RR 160")
# Out:
# 337

# %%
mytext = "      Koormustestid Veloergomeetria Teostatud: 07.02.2014 12:02  Tellimuse vastus nr: 14-38866-1 Koormustest VEM-l 25W/2m, koormatud 10:07 min:sek, saavutades Max. Load: 150 Watt . Rahuoleku pulsisagedus 62 x min , koormusel maksimaalne pulsisagedus 155 x min. Patsient saavutas   92 % ealisest maksimaalsest pulsisagedusest. Rahuoleku "

# %%
mytext
# Out:
# '       Koormustestid Veloergomeetria Teostatud: 07.02.2014 12:02  Tellimuse vastus nr: 14-38866-1 Koormustest VEM-l 25W/2m, koormatud 10:07 min:sek, saavutades Max. Load: 150 Watt . Rahuoleku pulsisagedus 62 x min , koormusel maksimaalne pulsisagedus 155 x min. Patsient saavutas   92 % ealisest maksimaalsest pulsisagedusest. Rahuoleku '

# %%
import re

# %%
len(re.sub(' +', ' ',mytext))
# Out:
# 328

# %%
len("Koormustestid Veloergomeetria Teostatud: 07.02.2014 12:02 Tellimuse vastus nr: 14-38866-1 Koormustest VEM-l 25W/2m, koormatud 10:07 min:sek, saavutades Max. Load: 150 Watt . Rahuoleku pulsisagedus 62 x min , koormusel maksimaalne pulsisagedus 155 x min. Patsient saavutas   92 % ealisest maksimaalsest pulsisagedusest. Rahuoleku ")
# Out:
# 329

# %%
DS[DS["text_ID"] == 357842]["text"]
# Out:
# 142    21.05.2014 N. <ANONYM id="2" type="per" morph="_H_ sg n"/> D00330 Kardiovaskulaarsüsteem Südame auskultatsioon ja perkussioon normis
# Name: text, dtype: object

# %%
DS[DS["text_ID"] == 357842]
# Out:
#      text_ID  start  end object  value unit  min   max  \
# 142  357842   9      20   RR     100.0  NaN NaN   60.0
#
#                                                                                                                                       text
# 142  21.05.2014 N. <ANONYM id="2" type="per" morph="_H_ sg n"/> D00330 Kardiovaskulaarsüsteem Südame auskultatsioon ja perkussioon normis

# %%
new_df[1:50]
# Out:
#     text_ID                    word  start    end     tag
# 1   45389    liigkaaluline.          0.0    14.0   O
# 2   45389    Nahk,                   15.0   20.0   O
# 3   45389    limaskestad             21.0   32.0   O
# 4   45389    tavalist                33.0   41.0   O
# 5   45389    värvust.                42.0   50.0   O
# 6   45389    Kopsudesvesikulaarneh.  51.0   73.0   O
# 7   45389    kahin,                  74.0   80.0   O
# 8   45389    räginaid                81.0   89.0   O
# 9   45389    ei                      90.0   92.0   O
# 10  45389    ole.                    93.0   97.0   O
# 11  45389    Südametoonid            98.0   110.0  O
# 12  45389    rütmilised              111.0  121.0  O
# 13  45389    74                      122.0  124.0  O
# 14  45389    x                       125.0  126.0  O
# 15  45389    min.                    127.0  131.0  O
# 16  45389    Kahinaid                132.0  140.0  O
# 17  45389    südamel                 141.0  148.0  O
# ...

# %% [markdown]
# ## ToDO
# * words, search 3la RR fl word
# * search fl text 3la RR w b3daha value w y2om wa5ed el index bta3hom, w b3d kda ay word bara el index dah tb2a unknown

# %%
new_df.loc[(new_df['tag']!="Target"), 'tag'] = "O"

# %%
new_df["word"].replace('', np.nan,inplace=True)
new_df = new_df.dropna(subset=['word'])
new_df = new_df.reset_index(drop=True)

# %%
new_df[200:250]
# Out:
#      text_ID                    word   start     end tag
# 200  71834    rahulikum,agresiivsust  1159.0  1181.0  O
# 201  71834    ei                      1182.0  1184.0  O
# 202  71834    avalda.                 1185.0  1192.0  O
# 203  71834    Ravimeid                1193.0  1201.0  O
# 204  71834    tarvitab.               1202.0  1211.0  O
# 205  71834    Uni                     1212.0  1215.0  O
# 206  71834    endiselt                1216.0  1224.0  O
# 207  71834    ärkamistega,            1225.0  1237.0  O
# 208  71834    Haige                   1238.0  1243.0  O
# 209  71834    nõus                    1244.0  1248.0  O
# 210  71834    jätkama                 1249.0  1256.0  O
# 211  71834    ravi                    1257.0  1261.0  O
# 212  71834    ambulatoorselt.         1262.0  1277.0  O
# 213  71834    Jätkab                  1278.0  1284.0  O
# 214  71834    ravi                    1285.0  1289.0  O
# 215  71834    Orfirili                1290.0  1298.0  O
# ...

# %%
new_df["tag"].value_counts()
# Out:
# O         63147
# Target    766
# Name: tag, dtype: int64

# %%
new_df.columns
# Out:
# Index(['text_ID', 'word', 'start', 'end', 'tag'], dtype='object')

# %%
data = new_df[['text_ID','word','tag']]
data.columns = ['sentence_idx','word','tag']

# %%
data.head()
# Out:
#    sentence_idx            word tag
# 0  45389         Kergelt         O
# 1  45389         liigkaaluline.  O
# 2  45389         Nahk,           O
# 3  45389         limaskestad     O
# 4  45389         tavalist        O

# %%
class SentenceGetter(object):
    
    def __init__(self, dataset):
        self.n_sent = 1
        self.dataset = dataset
        self.empty = False
        agg_func = lambda s: [(w, t) for w,t in zip(s["word"].values.tolist(),
                                                        s["tag"].values.tolist())]
        self.grouped = self.dataset.groupby("sentence_idx").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None
          
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
print(sentences[1:2])
# Out:
# [[('Kuupäev:', 'O'), ('14.08.2012', 'O'), ('09:01', 'O'), ('Kood', 'O'), ('ja', 'O'), ('nimetus:', 'O'), ('7903', 'O'), ('Röntgeniülesvõte', 'O'), ('rindkere', 'O'), ('piirkonnast', 'O'), ('(üks', 'O'), ('ülesvõte)', 'O'), ('Põhjendus:', 'O'), ('.', 'O'), ('Kirjeldus:', 'O'), ('Diafragmad', 'O'), ('selgekontuursed,', 'O'), ('VII', 'O'), ('roide', 'O'), ('kõrgusel,', 'O'), ('siinused', 'O'), ('vabad.', 'O'), ('Kopsutipud', 'O'), ('puhtad.', 'O'), ('Hiilused', 'O'), ('struktuuritud,', 'O'), ('laienenud,', 'O'), ('joonis', 'O'), ('alaväljadel', 'O'), ('rohkenenud.', 'O'), ('Kopsuväljades', 'O'), ('koldelisi', 'O'), ('ega', 'O'), ('infiltratiivseid', 'O'), ('muutuseid', 'O'), ('ei', 'Target'), ('näe.', 'Target'), ('Südamevari', 'Target'), ('ealine.', 'O'), ('Kuupäev:', 'O'), ('22.08.2012', 'O'), ('16:34', 'O'), ('Kood', 'O'), ('ja', 'O'), ('nimetus:', 'O'), ('6340', 'O'), ('Täismahus', 'O'), ('ehhokardiograafia', 'O'), ('Põhjendus:', 'O'), ('S-B', 'O'), ('Kirjeldus:', 'O'), ('Study', 'O'
# ...

# %%
from math import nan

words = list(set(data["word"].values))
n_words = len(words)

tags = []
for tag in set(data["tag"].values):
    if tag is nan or isinstance(tag, float):
        tags.append('unk')
    else:
        tags.append(tag)
n_tags = len(tags)

from future.utils import iteritems

word2idx = {w: i for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
idx2tag = {v: k for k, v in iteritems(tag2idx)}

# %%
len(words)
# Out:
# 19353

# %%
maxlen
# Out:
# 3206

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# maxlen = max([len(s) for s in sentences])
maxlen = 100
X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=maxlen, sequences=X, padding="post",value=n_words - 1)

y = [[tag2idx[w[1]] for w in s] for s in sentences]
y = pad_sequences(maxlen=maxlen, sequences=y, padding="post", value=tag2idx["O"])
y = [to_categorical(i, num_classes=n_tags) for i in y]

# Split train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from keras.models import Model, Input
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional
import keras as k
from keras_contrib.layers import CRF

input = Input(shape=(maxlen,))
word_embedding_size = 150

# Embedding Layer
model = Embedding(input_dim=n_words, output_dim=word_embedding_size, input_length=maxlen)(input)

# BI-LSTM Layer
model = Bidirectional(LSTM(units=word_embedding_size, 
                           return_sequences=True, 
                           dropout=0.5, 
                           recurrent_dropout=0.5, 
                           kernel_initializer=k.initializers.he_normal()))(model)
model = LSTM(units=word_embedding_size * 2, 
             return_sequences=True, 
             dropout=0.5, 
             recurrent_dropout=0.5, 
             kernel_initializer=k.initializers.he_normal())(model)

# TimeDistributed Layer
model = TimeDistributed(Dense(n_tags, activation="relu"))(model)  

# CRF Layer
crf = CRF(n_tags)

out = crf(model)  # output
model = Model(input, out)

# %%
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

#Optimiser 
adam = k.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.999)

# Compile model
model.compile(optimizer=adam, loss=crf.loss_function, metrics=[crf.accuracy, 'accuracy'])

model.summary()

# Saving the best model only
filepath="ner-bi-lstm-td-model-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fit the best model
history = model.fit(X_train, np.array(y_train), batch_size=256, epochs=10, validation_split=0.1, verbose=1, callbacks=callbacks_list)
# Out:
# C:\Users\Kasutaja\Anaconda3\envs\myEnv\lib\site-packages\keras_contrib-2.0.8-py3.7.egg\keras_contrib\layers\crf.py:346: UserWarning: CRF.loss_function is deprecated and it might be removed in the future. Please use losses.crf_loss instead.
# C:\Users\Kasutaja\Anaconda3\envs\myEnv\lib\site-packages\keras_contrib-2.0.8-py3.7.egg\keras_contrib\layers\crf.py:353: UserWarning: CRF.accuracy is deprecated and it might be removed in the future. Please use metrics.crf_accuracy
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 150)          2902950
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100, 300)          361200
# ...

# %%
# Plot the graph 
plt.style.use('ggplot')

def plot_history(history):
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(accuracy) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, accuracy, 'b', label='Training acc')
    plt.plot(x, val_accuracy, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

plot_history(history)

# %%
def pred2label(pred):
    out = []
    for pred_i in pred:
        out_i = []
        for p in pred_i:
            p_i = np.argmax(p)
            out_i.append(idx2tag[p_i])
        out.append(out_i)
    return out
test_pred = model.predict(X_test, verbose=1)   
pred_labels = pred2label(test_pred)
test_labels = pred2label(y_test)
# Out:
# 99/99 [==============================] - 1s 8ms/step

# %%
from seqeval.metrics import precision_score, recall_score, f1_score, classification_report
print("F1-score: {:.1%}".format(f1_score(test_labels, pred_labels)))
# Out:
# F1-score: 0.0%

# %%
from  sklearn_crfsuite.metrics import flat_classification_report  
report = flat_classification_report(y_pred=pred_labels, y_true=test_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            O       0.99      1.00      0.99      9768
#       Target       0.00      0.00      0.00       132
#
#     accuracy                           0.99      9900
#    macro avg       0.49      0.50      0.50      9900
# weighted avg       0.97      0.99      0.98      9900
# C:\Users\Kasutaja\Anaconda3\envs\myEnv\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
TP = {}
TN = {}
FP = {}
FN = {}
for tag in tag2idx.keys():
    TP[tag] = 0
    TN[tag] = 0    
    FP[tag] = 0    
    FN[tag] = 0    

def accumulate_score_by_tag(gt, pred):
    """
    For each tag keep stats
    """
    if gt == pred:
        TP[gt] += 1
    elif gt != 'O' and pred == 'O':
        FN[gt] +=1
    elif gt == 'O' and pred != 'O':
        FP[gt] += 1
    else:
        TN[gt] += 1
for i, sentence in enumerate(X_test):
    y_hat = np.argmax(test_pred[0], axis=-1)
    gt = np.argmax(y_test[0], axis=-1)
    for idx, (w,pred) in enumerate(zip(sentence,y_hat)):
        accumulate_score_by_tag(idx2tag[gt[idx]],tags[pred])
for tag in tag2idx.keys():
    print(f'tag:{tag}')    
    print('\t TN:{:10}\tFP:{:10}'.format(TN[tag],FP[tag]))
    print('\t FN:{:10}\tTP:{:10}'.format(FN[tag],TP[tag]))
#Reference: https://www.kaggle.com/nikkisharma536/ner-with-bilstm-and-crf/notebook
# Out:
# tag:Target
# 	 TN:         0	FP:         0
# 	 FN:         0	TP:         0
# tag:O
# 	 TN:         0	FP:         0
# 	 FN:         0	TP:      9900

# %%
DSCpy = new_df.copy()

# %%
DSCpy.head()
# Out:
#    text_ID            word  start   end tag  NewTag
# 0  45389    Kergelt        NaN    NaN    O  NaN
# 1  45389    liigkaaluline.  0.0    14.0  O  NaN
# 2  45389    Nahk,           15.0   20.0  O  NaN
# 3  45389    limaskestad     21.0   32.0  O  NaN
# 4  45389    tavalist        33.0   41.0  O  NaN

# %%
DSCpy["NewTag"] = np.nan

# %%
DSSubset.columns
# Out:
# Index(['text_ID', 'start', 'end', 'object', 'value', 'unit', 'min', 'max',
#        'text'],
#       dtype='object')

# %%
# for i in range(len(DSSubset)):
# #     for j in range(len(DSCpy)):
#     DSCpy[DSCpy["text_ID"] == DSSubset["text_ID"][i]]
#         if(DSSubset["text_ID"][i] == DSCpy["text_ID"][j]):
#             DSSubset["object"][i] 
            
            
myList= list(DSSubset.text_ID.unique())
for i in range(len(myList)):
# for i in range(1,5):
    Original = DSSubset.loc[DSSubset["text_ID"] == myList[i]]
    words = DSCpy.loc[DSCpy["text_ID"] == myList[i]]
#     print(words)
    for OriginalIndex, OriginalRow in Original.iterrows():
        for index, row in words.iterrows():
                if(str(Original["object"][OriginalIndex]) in str(words["word"][index])):
                    DSCpy["NewTag"][index] = "object"
                    if()
                elif(str(int(Original["value"][OriginalIndex])) in str(words["word"][index])):
                    DSCpy["NewTag"][index] = "value"
# Out:
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Kasutaja\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
DSCpy.drop("tag",inplace=True, axis=1)

# %%
DSCpy[DSCpy["NewTag"] == "object"][0:50]
# Out:
#       text_ID            word   start     end  NewTag
# 20    45389    RR              157.0   159.0   object
# 38    47482    RR142/89mmHg,   0.0     13.0    object
# 50    53393    RR143/87mmHg,   0.0     13.0    object
# 56    53571    RR              0.0     2.0     object
# 139   71834    RR              475.0   477.0   object
# 332   83834    RR              791.0   793.0   object
# 386   87007    RR              124.0   126.0   object
# 477   87007    RR6344          833.0   839.0   object
# 490   87007    RR              944.0   946.0   object
# 494   87007    RR              965.0   967.0   object
# 499   87007    RR              999.0   1001.0  object
# 503   87007    RR              1020.0  1022.0  object
# 508   87007    RR              1051.0  1053.0  object
# 512   87007    RR              1072.0  1074.0  object
# 525   87007    RR              1208.0  1210.0  object
# 830   108715   RR              0.0     2.0     object
# ...

# %%
DSCpy[DSCpy["NewTag"] == "value"][0:50]
# Out:
#       text_ID                word   start     end NewTag
# 21    45389    110/75              160.0   166.0   value
# 57    53571    140/74              3.0     9.0     value
# 140   71834    95/                 478.0   481.0   value
# 333   83834    120/70              794.0   800.0   value
# 831   108715   130/80              3.0     9.0     value
# 1206  56118    130/80.             1297.0  1304.0  value
# 1360  73320    110/80-125/75mmHg.  884.0   902.0   value
# 1364  75690    193/112             14.0    21.0    value
# 1549  85153    135/90              1165.0  1171.0  value
# 1715  89810    149.                488.0   492.0   value
# 1820  100914   123/85,             307.0   314.0   value
# 1862  121806   96.0                176.0   180.0   value
# 1884  121806   (11,6               259.0   264.0   value
# 1897  121806   3.6                 306.0   309.0   value
# 1900  121806   6                   316.0   317.0   value
# ...

# %%
history = model.fit(X_train, np.array(y_train), batch_size=256, epochs=10, validation_split=0.1, verbose=1, callbacks=callbacks_list)
